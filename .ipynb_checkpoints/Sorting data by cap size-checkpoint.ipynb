# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# u'0.20.3+0.g3a7f956c3.dirty'

# %%
data = pd.read_csv("Large_cap.csv")
data.head()
# Out:
#   Symbol                 Name  LastSale     MarketCap ADR TSO IPOyear  \
# 0    MMM           3M Company    229.36  1.366087e+11     n/a     n/a
# 1   WUBA          58.com Inc.     74.80  1.095896e+10     n/a    2013
# 2    ABB              ABB Ltd     25.23  5.385221e+10     n/a     n/a
# 3    ABT  Abbott Laboratories     55.56  9.670777e+10     n/a     n/a
# 4   ABBV          AbbVie Inc.     93.61  1.494418e+11     n/a    2012
#
#               Sector                                         Industry  \
# 0        Health Care                       Medical/Dental Instruments
# 1         Technology  Computer Software: Programming, Data Processing
# 2  Consumer Durables                              Electrical Products
# 3        Health Care                            Major Pharmaceuticals
# 4        Health Care                            Major Pharmaceuticals
#
#                        Summary Quote  Unnamed: 9
# 0   http://www.nasdaq.com/symbol/mmm         NaN
# 1  http://www.nasdaq.com/symbol/wuba         NaN
# 2   http://www.nasdaq.com/symbol/abb         NaN
# 3   http://www.nasdaq.com/symbol/abt         NaN
# 4  http://www.nasdaq.com/symbol/abbv         NaN

# %%
data = data.iloc[:,0:4]

# %%
data = data.sort_values("MarketCap")
data.index = range(len(data))

# %%
data
# Out:
#     Symbol                                         Name  LastSale  \
# 0     ARMK                                      Aramark     40.82
# 1      VAR                 Varian Medical Systems, Inc.    109.03
# 2      PNW            Pinnacle West Capital Corporation     90.05
# 3      DVA                                  DaVita Inc.     54.91
# 4      TRU                                   TransUnion     55.29
# 5      AOS                     Smith (A.O.) Corporation     58.89
# 6      ACH        Aluminum Corporation of China Limited     17.13
# 7      DRI                     Darden Restaurants, Inc.     82.81
# 8      LNT                   Alliant Energy Corporation     44.40
# 9      DRE                      Duke Realty Corporation     28.84
# 10     IHG                Intercontinental Hotels Group     56.55
# 11     PVH                                    PVH Corp.    133.12
# 12     MBT                      Mobile TeleSystems OJSC     10.57
# 13     AMG              Affiliated Managers Group, Inc.    186.09
# 14     AEM                   Agnico Eagle Mines Limited     44.60
# 15     HNP            Huaneng Power International, Inc.     27.27
# 16      BR         Broadridge Financial Solutions, Inc.     89.25
# 17     UDR           United Dominion Realty Trust, Inc.     39.17
# 18     ASX     Advanced Semiconductor Engineering, Inc.      6.21
# 19     SEE                       Sealed Air Corporation     45.72
# 20     ALV                                Autoliv, Inc.    121.19
# 21     HII          Huntington Ingalls Industries, Inc.    232.87
# 22     SJR                     Shaw Communications Inc.     22.18
# 23    BRFS                                     BRF S.A.     13.01
# 24      IT                                Gartner, Inc.    116.90
# 25     PKG             Packaging Corporation of America    112.47
# 26     KSU                         Kansas City Southern    102.67
# 27     IRM                   Iron Mountain Incorporated     40.77
# 28     BWA                              BorgWarner Inc.     51.94
# 29    WUBA                                  58.com Inc.     74.80
# ..     ...                                          ...       ...
# 478    SNY                                       Sanofi     44.54
# 479     RY                         Royal Bank Of Canada     79.03
# 480    PTR                   PetroChina Company Limited     66.97
# 481     MO                                 Altria Group     66.42
# 482    NVO                             Novo Nordisk A/S     50.91
# 483     BP                                    BP p.l.c.     39.09
# 484    MCD                   McDonald&#39;s Corporation    166.72
# 485    SAP                                       SAP SE    113.75
# 486    MMM                                   3M Company    229.36
# 487    IBM  International Business Machines Corporation    148.97
# 488    TOT                                   Total S.A.     54.78
# 489   ABBV                                  AbbVie Inc.     93.61
# 490    MRK                        Merck & Company, Inc.     55.20
# 491    BTI              British American Tobacco p.l.c.     66.18
# 492     BA                         Boeing Company (The)    262.26
# 493     GE                     General Electric Company     18.21
# 494     UL                                 Unilever PLC     55.00
# 495     PM              Philip Morris International Inc    102.64
# 496    DIS                    Walt Disney Company (The)    103.44
# 497     UN                                  Unilever NV     56.22
# 498    PEP                                Pepsico, Inc.    114.68
# 499     MA                      Mastercard Incorporated    149.02
# 500   DWDP                               DowDuPont Inc.     70.74
# 501     TM                    Toyota Motor Corp Ltd Ord    123.29
# 502     VZ                  Verizon Communications Inc.     45.42
# 503      C                               Citigroup Inc.     71.33
# 504   HSBC                            HSBC Holdings plc     48.28
# 505     KO                      Coca-Cola Company (The)     45.71
# 506    NVS                                  Novartis AG     83.98
# 507     HD                       Home Depot, Inc. (The)    167.74
#
#         MarketCap
# 0    1.000519e+10
# 1    1.000905e+10
# 2    1.006127e+10
# 3    1.006500e+10
# 4    1.008425e+10
# 5    1.012493e+10
# 6    1.021208e+10
# 7    1.024138e+10
# 8    1.026547e+10
# 9    1.027110e+10
# 10   1.028677e+10
# 11   1.030674e+10
# 12   1.033132e+10
# 13   1.034324e+10
# 14   1.035671e+10
# 15   1.036286e+10
# 16   1.040231e+10
# 17   1.048800e+10
# 18   1.050575e+10
# 19   1.051544e+10
# 20   1.053785e+10
# 21   1.053999e+10
# 22   1.054284e+10
# 23   1.055293e+10
# 24   1.059715e+10
# 25   1.061160e+10
# 26   1.063077e+10
# 27   1.088303e+10
# 28   1.095095e+10
# 29   1.095896e+10
# ..            ...
# 478  1.125200e+11
# 479  1.148225e+11
# 480  1.225691e+11
# 481  1.267420e+11
# 482  1.273743e+11
# 483  1.290302e+11
# 484  1.329068e+11
# 485  1.363435e+11
# 486  1.366087e+11
# 487  1.379151e+11
# 488  1.380546e+11
# 489  1.494418e+11
# 490  1.503889e+11
# 491  1.517911e+11
# 492  1.561964e+11
# 493  1.579187e+11
# 494  1.585828e+11
# 495  1.594207e+11
# 496  1.596577e+11
# 497  1.621004e+11
# 498  1.630914e+11
# 499  1.652459e+11
# 500  1.655309e+11
# 501  1.809148e+11
# 502  1.852882e+11
# 503  1.885967e+11
# 504  1.929003e+11
# 505  1.947551e+11
# 506  1.967567e+11
# 507  1.977349e+11
#
# [508 rows x 4 columns]

# %%
data = pd.read_excel("test.xlsx")
data
# Out:
#   SYMBOL     P/E    ROE  CF/NI    D/A   EPS    REV
# 0   AAPL   19.00  0.369    1.3  0.308  9.19  0.063
# 1   MSFT   30.10  0.289    1.9  0.358  2.68  0.054
# 2     FB   35.10  0.243    1.6  0.000  5.16  0.542
# 3    AMZ  292.94  0.091    6.9  0.245  3.95  0.271

# %%
data.index = data.iloc[:,0]

# %%
data = data.iloc[:,1:]

# %%
data
# Out:
#            P/E    ROE  CF/NI    D/A   EPS    REV
# SYMBOL
# AAPL     19.00  0.369    1.3  0.308  9.19  0.063
# MSFT     30.10  0.289    1.9  0.358  2.68  0.054
# FB       35.10  0.243    1.6  0.000  5.16  0.542
# AMZ     292.94  0.091    6.9  0.245  3.95  0.271

# %%
matrx_data.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-890dfa55ecd4> in <module>()
# ----> 1 index(matrx_data)
#
# NameError: name 'index' is not defined

# %%
matrx_data = data.as_matrix()
# Out:
# array([  5.03833333,   5.89683333,   7.1075    ,  50.73283333])

# %%
dat_mean = data.apply(np.mean, 0)
type(dat_mean)
# Out:
# pandas.core.series.Series

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(matrx_data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
# Coefficients
pca.components_
# Out:
# array([[  9.99772691e-01,  -8.08016561e-04,   2.00168174e-02,
#           4.74843834e-05,  -7.29194207e-03,   2.56761227e-04],
#        [  8.35438626e-03,   1.25668850e-02,  -5.29282499e-02,
#          -1.92917831e-04,   9.98445377e-01,  -8.81307346e-03]])

# %%
pca.explained_variance_ratio_
# Out:
# array([  9.99595476e-01,   3.99352118e-04])

# %%
score = np.matmul(pca.components_ , matrx_data.T)

# %%
score_df = pd.DataFrame(score,index = ['PC1','PC2'],columns = data.index)

# %%
import matplotlib.pyplot as plt

# %%
score_df
# Out:
# SYMBOL       AAPL       MSFT         FB         AMZ
# PC1     18.954423  30.111445  35.086365  292.982733
# PC2      9.269662   2.829824   5.358809    6.024696

# %%
plt.plot(score_df.iloc[0,:],score_df.iloc[1,:],'.')
plt.show()
