# %%
from lib.env.global_var import *
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-62211f24f2ca> in <module>()
# ----> 1 from lib.env.global_var import *
#       2 import pandas as pd
#       3 import numpy as np
#
# ImportError: No module named lib.env.global_var

# %%
# %store -r top_sector

# %%
top_sector.head(5)
# Out:
#             IDU US Equity  IYE US Equity  IYF US Equity  IYJ US Equity  \
# 2000-08-31           True          False          False           True
# 2000-09-29           True           True           True          False
# 2000-10-31          False          False          False          False
# 2000-11-30           True          False          False          False
# 2000-12-29          False           True           True          False
#
#             IYK US Equity  IYM US Equity  IYW US Equity  IYZ US Equity
# 2000-08-31          False          False           True          False
# 2000-09-29          False          False          False          False
# 2000-10-31           True           True          False           True
# 2000-11-30           True           True          False          False
# 2000-12-29          False           True          False          False

# %%
folder_dir_str = data_path
econ_dir_str = econ_data_path

BENCHMARK = "benchmark_data.xlsx" # benchmark for 9 sectors

#Customer Price Index Growth, Customer Sentimental, Government 10-y interest rate, 
#Fed Fund rate, Gross Domestic Products, Home Price Indices, Net Expenditures, Options-Adjusted Spread,
#Payroll, Consumption Expenditures, Recession probability, Counterparty Credit Risk,
#Unemployment rate, SP500 Volatility
var_list = ['CPI','CSENT', 'DGS10', 'FEDFUNDS', 'GDP', 'HPI', 'NETEXP', 'OAS', 'PAYEMS',
          'PCE', 'RECESSION', 'TEDRATE', 'UNRATE', 'VIXCLS']

# %%
def quaterly_to_monthly(df):
    # if the index is not pd.DatetimeIndex, convert it
    if type(df.index) != pd.DatetimeIndex:
        df.index = pd.DatetimeIndex(df.index)
        
    resampled_df = df.resample("M").last()
    for int_index in range(len(resampled_df)):
        value = resampled_df.iloc[int_index,:].values[0]
        if not np.isnan(value):
            # copy quater data
            previouse_quater = value
            quater_index = 1
        if np.isnan(value) and quater_index ==1:
            # filling first value
            resampled_df.iloc[int_index,:] = previouse_quater
            quater_index += 1
        if np.isnan(value) and quater_index ==2:
            # filling the second value
            resampled_df.iloc[int_index,:] = previouse_quater
            quater_index = 1
    return(resampled_df)

# %%
# return time series of the input file
def read_format_csv(filename, filepath, varname='VAR'):
    dat_csv = pd.read_csv(filepath+filename)
    map(str, dat_csv.columns)
    dat_csv.columns = ['DATE', varname]
    dat_dte = dat_csv.loc[:, 'DATE']
    dat_csv.index = dat_dte.values
    
    dat_csv = (dat_csv.loc[:, [varname]].replace('.',0)).astype(float)
    return dat_csv

# %%
#merge benchmark data time series with all fundamentals
def get_bm_fundamental_ts(benchmark, var_list):
    for var in var_list:
        var_file_name = var +'.csv'
        tmp = read_format_csv(var_file_name, econ_dir_str, var)
        exec(var+"_ts = tmp")
        
    for var in ['CPI', 'GDP', 'NETEXP']:
        exec("tmp ="+var+"_ts")
        filltmp = quaterly_to_monthly(tmp)
        exec(var+"_ts = filltmp")
        
    ts_df = benchmark
    for var in var_list:
        exec('tmp_csv = '+var+'_ts')
        tmp_csv.index = pd.DatetimeIndex(tmp_csv.index)
        tmp_concat = pd.concat([ts_df, tmp_csv], 1)
        tmp_concat = tmp_concat.resample("M").last()
        ts_df = tmp_concat.loc[ts_df.index[0]:tmp_csv.index[-1], :]

    return ts_df

# %%
numInd = len(top_sector.columns)
for ind in range(numInd):
    bm = top_sector.iloc[:,[ind]]
    bm_res = bm.resample("M").last()
    
    tmp = get_bm_fundamental_ts(bm_res, var_list)
    bmname = bm.columns[0].replace(" ", "_")
    exec(bmname+'_df = tmp')

# %%
top_sector.iloc[:,[0]].columns[0].replace(" ", "_")+'_df'
# Out:
# u'IDU_US_Equity_df'

# %%
IDU_US_Equity_df.tail(10)
# Out:
#            IDU US Equity  CPI  CSENT  DGS10  FEDFUNDS        GDP     HPI  \
# 2017-01-31         False  0.8   98.5   2.45      0.65  19057.705  184.95
# 2017-02-28           NaN  NaN   96.3   2.36      0.66  19057.705  185.33
# 2017-03-31           NaN  NaN   96.9   2.40      0.79  19057.705  186.83
# 2017-04-30           NaN  NaN   97.0   2.29      0.90  19250.009  188.84
# 2017-05-31           NaN  NaN   97.1   2.21      0.91  19250.009  190.92
# 2017-06-30           NaN  NaN   95.1   2.31      1.04  19250.009  192.66
# 2017-07-31           NaN  NaN   93.4   2.30      1.15  19495.476  194.01
# 2017-08-31           NaN  NaN    NaN    NaN       NaN        NaN     NaN
# 2017-09-30           NaN  NaN    NaN    NaN       NaN        NaN     NaN
# 2017-10-31           NaN  NaN    NaN    NaN       NaN        NaN     NaN
#
#              NETEXP   OAS    PAYEMS      PCE  RECESSION  TEDRATE  UNRATE  \
# 2017-01-31 -582.844  4.00  145541.0  13160.0       0.26     0.51     4.8
# 2017-02-28 -582.844  3.74  145773.0  13175.0       0.14     0.53     4.7
# 2017-03-31 -582.844  3.92  145823.0  13239.7       0.12     0.40     4.5
# 2017-04-30 -567.236  3.81  146030.0  13281.7       0.06     0.38     4.4
# 2017-05-31 -567.236  3.74  146175.0  13310.3       0.08     0.25     4.3
# 2017-06-30 -567.236  3.77  146385.0  13329.1       0.26     0.29     4.4
# 2017-07-31 -531.687  3.61  146523.0  13377.7       0.92     0.26     4.3
# 2017-08-31      NaN   NaN       NaN      NaN        NaN     0.33     4.4
# 2017-09-30      NaN   NaN       NaN      NaN        NaN     0.29     4.2
# 2017-10-31      NaN   NaN       NaN      NaN        NaN      NaN     NaN
#
#             VIXCLS
# 2017-01-31   11.99
# 2017-02-28   12.92
# 2017-03-31   12.37
# 2017-04-30   10.82
# 2017-05-31   10.41
# 2017-06-30   11.18
# 2017-07-31   10.26
# 2017-08-31   10.59
# 2017-09-30    9.51
# 2017-10-31   10.18

# %%
N = len(top_sector.columns)
for i in range(N):
    str = top_sector.iloc[:,[i]].columns[0]
    bm_df_name = str.replace(" ", "_")+'_df'
    print(bm_df_name +' = ' + bm_df_name + '.dropna(axis=0, how="any")')
    exec(bm_df_name +' = ' + bm_df_name + '.dropna(axis=0, how="any")')
# Out:
# IDU_US_Equity_df = IDU_US_Equity_df.dropna(axis=0, how="any")
# IYE_US_Equity_df = IYE_US_Equity_df.dropna(axis=0, how="any")
# IYF_US_Equity_df = IYF_US_Equity_df.dropna(axis=0, how="any")
# IYJ_US_Equity_df = IYJ_US_Equity_df.dropna(axis=0, how="any")
# IYK_US_Equity_df = IYK_US_Equity_df.dropna(axis=0, how="any")
# IYM_US_Equity_df = IYM_US_Equity_df.dropna(axis=0, how="any")
# IYW_US_Equity_df = IYW_US_Equity_df.dropna(axis=0, how="any")
# IYZ_US_Equity_df = IYZ_US_Equity_df.dropna(axis=0, how="any")

# %% [markdown]
# Scaled Data Preprocessing

# %%
from sklearn import preprocessing
selected_bm = IYW_US_Equity_df
attributes = selected_bm.iloc[:,1:].columns
data_scaled = preprocessing.scale(selected_bm.iloc[:,1:].values, axis = 0)
data_scaled
data_scaled = pd.DataFrame(data_scaled, columns = attributes)
data_scaled
# Out:
#           CPI     CSENT     DGS10  FEDFUNDS       GDP       HPI    NETEXP  \
# 0    0.380780  2.130521  1.867085  2.516686 -1.682382 -2.119997  1.354455
# 1    0.380780  2.086740  1.923148  2.527063 -1.682382 -2.091752  1.354455
# 2   -0.026758  1.999177  1.899121  2.521875 -1.635834 -2.064874  1.242036
# 3   -0.026758  2.156790  1.666858  2.521875 -1.635834 -2.039362  1.242036
# 4   -0.026758  1.351211  1.378531  2.464803 -1.635834 -2.016584  1.242036
# 5    0.652472  1.027228  1.434595  2.246895 -1.621309 -1.996995  1.328499
# 6    0.652472  0.668220  1.218350  1.992669 -1.621309 -1.977861  1.328499
# 7    0.652472  0.747027  1.226359  1.899280 -1.621309 -1.943239  1.328499
# 8    0.652472  0.475582  1.562740  1.634677 -1.568510 -1.904516  1.590872
# 9    0.652472  0.790808  1.626812  1.328568 -1.568510 -1.861237  1.590872
# 10   0.652472  0.843346  1.618803  1.204050 -1.568510 -1.812492  1.590872
# 11  -0.570141  0.825833  1.338486  1.100284 -1.568063 -1.768758  1.531395
# 12  -0.570141  0.747027  1.162286  1.038024 -1.568063 -1.734135  1.531395
# 13  -0.570141 -0.102334  0.962059  0.737104 -1.568063 -1.712268  1.531395
# 14  -1.113525 -0.023527  0.721787  0.436183 -1.543001 -1.702701  1.609384
# 15  -1.113525  0.081549  1.106223  0.228652 -1.543001 -1.695412  1.609384
# 16  -1.113525  0.510607  1.338486  0.088568 -1.543001 -1.685390  1.609384
# 17  -0.162603  0.878371  1.338486  0.041873 -1.489041 -1.668079  1.461684
# 18  -0.162603  0.676976  1.186313  0.047061 -1.489041 -1.646212  1.461684
# 19  -0.162603  1.114791 -2.722114  0.041873 -1.489041 -1.600200  1.461684
# 20   0.788318  0.878371  1.370522  0.052250 -1.448383 -1.541888  1.131539
# 21   0.788318  1.219867  1.346495  0.052250 -1.448383 -1.469909  1.131539
# 22   0.788318  0.825833  1.170295  0.052250 -1.448383 -1.399752  1.131539
2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31',
#                '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30',
#                '2016-12-31', '2017-01-31'],
#               dtype='datetime64[ns]', length=198, freq='M')

# %%
data_target = pd.to_numeric(selected_bm.iloc[:,0].values)
data_target
# Out:
# array([ True, False, False, False, False,  True, False, False,  True,
#        False,  True, False, False, False,  True,  True, False,  True,
#        False,  True, False, False, False, False, False, False,  True,
#         True, False,  True,  True, False, False,  True, False,  True,
#         True, False,  True, False, False,  True, False, False, False,
#         True, False, False, False,  True,  True, False, False, False,
#        False, False, False,  True, False,  True, False, False, False,
#         True, False,  True, False, False, False, False, False, False,
#         True,  True, False,  True, False, False, False, False,  True,
#        False,  True, False,  True,  True,  True, False,  True, False,
#        False,  True, False,  True, False, False,  True, False,  True,
#        False,  True,  True,  True,  True, False, False,  True, False,
#        False, False,  True, False,  True, False,  True, False, False,
#        False, False, False, False,  True,  True, False, False,  True,
#        False, False, False, False, False,  True, False,  True, False,
#        False, False,  True,  True,  True, False, False, False, False,
#         True, False, False,  True, False, False, False, False, False,
#         True, False, False,  True, False,  True,  True, False,  True,
#         True, False, False,  True,  True,  True, False,  True, False,
#         True, False, False,  True, False,  True,  True, False, False,
#        False,  True, False, False, False, False, False,  True, False,
#         True, False,  True,  True,  True,  True, False, False,  True], dtype=bool)

# %% [markdown]
# Logistic Regression

# %%
from sklearn import linear_model
logreg = linear_model.LogisticRegression(C=1e5, multi_class = 'ovr')
N_train = len(data_target)*3/4

Y = data_target[0:N_train]
X = data_scaled.iloc[0:N_train,:]
#X = data_scaled.iloc[0:N_train,:].shift()/data_scaled.iloc[0:N_train,:]-1
#X = X.dropna()
#Y = Y[1:]

logreg.fit(X, Y)
# Out:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# Benchmark Attributes

# %%
print(pd.DataFrame(logreg.coef_, columns = attributes))
# Out:
#         CPI     CSENT     DGS10  FEDFUNDS       GDP       HPI    NETEXP  \
# 0 -0.276044 -0.547565 -0.393032 -0.287582  5.274521 -0.118027  0.188127
#
#         OAS    PAYEMS       PCE  RECESSION   TEDRATE    UNRATE    VIXCLS
# 0 -0.275818  2.251288 -7.623471  -0.054511  0.090401  0.962427 -0.246109

# %%
X_test = data_scaled.iloc[N_train:,:]
#X_test = data_scaled.iloc[N_train:,:].shift()/data_scaled.iloc[N_train:,:]-1
#X_test = X_test.dropna()

y_test = logreg.predict(X_test)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.plot(Y,'r-',alpha =0.7)
plt.plot(np.concatenate([np.repeat(np.nan,len(Y)),y_test]),'b--')
plt.plot(np.concatenate([np.repeat(np.nan,len(Y)),data_target[N_train:]]), 'g-')
plt.show()

# %%
comparison_df = pd.concat([pd.DataFrame(y_test,columns=['y_test']),pd.DataFrame(data_target[N_train:],columns = ['real'])],1).dropna()
score_df = pd.DataFrame(map(lambda x: x[0]==x[1],comparison_df.values))*1
score = np.mean(score_df)

print("prediction rate: ",np.round(score.values[0]*100,3),"%")
# Out:
# ('prediction rate: ', 52.0, '%')
