# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

# %%
data_folder_dir = '/home/luke/workspace/backup/Investible-Stocks-Selection/data/CFRM521_final_project'
file_dir = os.path.join(data_folder_dir,'benchmark_data.xlsx')

# %%
data = pd.read_excel(file_dir,1)
data.index = data.iloc[:,0].values
data = data.iloc[:,[1]]
data.head()
# Out:
#             IYZ US Equity
# 2000-05-31        57.6250
# 2000-06-30        60.2813
# 2000-07-31        55.4375
# 2000-08-31        54.0625
# 2000-09-29        51.1875

# %%
n = 5

kf = KFold(n_splits=n)
kf.get_n_splits(data)
# Out:
# 5

# %%
train_dict ={}
test_dict = {}
ind = 1
for train_index, test_index in kf.split(data):
    x_train, x_test = data.iloc[train_index,:],data.iloc[test_index,:]
    train_dict[ind] = x_train
    test_dict[ind] = x_test
    ind += 1

# %%
# Out:
# [1, 2, 3]

# %%
for select_index in range(1,n+1):
    plt.figure(figsize = (15,5))
    plt.plot(train_dict[select_index],'r.')
    plt.plot(test_dict[select_index],'b.')
    plt.show()
